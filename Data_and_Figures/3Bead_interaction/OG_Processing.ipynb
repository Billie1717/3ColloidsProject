# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
import pandas
import numpy as np
import matplotlib.pyplot as plt
import os.path
datadir = '/Users/billiemeadowcroft/Dropbox/Tether/Plotting/'
plotsdir = '/Users/billiemeadowcroft/Dropbox/Tether/Plotting/Plots/3Bead_wrap/'
#datadir = '/Users/billie/Dropbox/Tether/Plotting/'
#plotsdir = '/Users/billie/Dropbox/Tether/Plotting/Plots/3Bead_wrap/'
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Data

# %%
fname1 = 'Excessr16tau0.dat'
LenA = 22 #21
LenW = 1
a_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [0], header = None)
a__ = a_.values
a = np.reshape(a__,(LenW,LenA))
Excess16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [1], header = None)
Excess16__ = Excess16_.values
ExcessR16 = np.reshape(Excess16__,(LenW,LenA))

Bending16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [3], header = None)
Bending16__ = Bending16_.values
Bending16 = np.reshape(Bending16__,(LenW,LenA))

Binding16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [4], header = None)
Binding16__ = Binding16_.values
Binding16 = np.reshape(Binding16__,(LenW,LenA))

Stretch16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [2], header = None)
Stretch16__ = Stretch16_.values
Stretch16 = np.reshape(Stretch16__,(LenW,LenA))

STDExcess16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [5], header = None)
STDExcess16__ = STDExcess16_.values
STDExcessR16 = np.reshape(STDExcess16__,(LenW,LenA))

STDBend16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [7], header = None)
STDBend16__ = STDBend16_.values
STDBend16 = np.reshape(STDBend16__,(LenW,LenA))

STDBind16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [8], header = None)
STDBind16__ = STDBind16_.values
STDBind16 = np.reshape(STDBind16__,(LenW,LenA))

STDStretch16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [6], header = None)
STDStretch16__ = STDStretch16_.values
STDStretch16 = np.reshape(STDStretch16__,(LenW,LenA))

fname11 = 'Excessr18tau0.dat'
LenA = 15 #13
a_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [0], header = None)
a__ = a_.values
a18 = np.reshape(a__,(LenW,LenA))
Excess18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [1], header = None)
Excess18__ = Excess18_.values
ExcessR18 = np.reshape(Excess18__,(LenW,LenA))

Bending18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [3], header = None)
Bending18__ = Bending18_.values
Bending18 = np.reshape(Bending18__,(LenW,LenA))

Binding18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [4], header = None)
Binding18__ = Binding18_.values
Binding18 = np.reshape(Binding18__,(LenW,LenA))

Stretch18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [2], header = None)
Stretch18__ = Stretch18_.values
Stretch18 = np.reshape(Stretch18__,(LenW,LenA))

STDExcess18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [5], header = None)
STDExcess18__ = STDExcess18_.values
STDExcessR18 = np.reshape(STDExcess18__,(LenW,LenA))

STDBend18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [7], header = None)
STDBend18__ = STDBend18_.values
STDBend18 = np.reshape(STDBend18__,(LenW,LenA))

STDBind18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [8], header = None)
STDBind18__ = STDBind18_.values
STDBind18 = np.reshape(STDBind18__,(LenW,LenA))

STDStretch18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [6], header = None)
STDStretch18__ = STDStretch18_.values
STDStretch18 = np.reshape(STDStretch18__,(LenW,LenA))



fname2 = 'Excessr32tau0.dat'
lenA = 21 #22
Excess32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [1], header = None)
Excess32__ = Excess32_.values
ExcessR32 = np.reshape(Excess32__,(LenW,lenA))
a_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [0], header = None)
a__ = a_.values
a32 = np.reshape(a__,(LenW,lenA))
STDExcess32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [5], header = None)
STDExcess32__ = STDExcess32_.values
STDExcessR32 = np.reshape(STDExcess32__,(LenW,lenA))

Bending32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [3], header = None)
Bending32__ = Bending32_.values
Bending32 = np.reshape(Bending32__,(LenW,lenA))

Binding32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [4], header = None)
Binding32__ = Binding32_.values
Binding32 = np.reshape(Binding32__,(LenW,lenA))

Stretch32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [2], header = None)
Stretch32__ = Stretch32_.values
Stretch32 = np.reshape(Stretch32__,(LenW,lenA))

STDBind32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [8], header = None)
STDBind32__ = STDBind32_.values
STDBind32 = np.reshape(STDBind32__,(LenW,lenA))

STDBend32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [7], header = None)
STDBend32__ = STDBend32_.values
STDBend32 = np.reshape(STDBend32__,(LenW,lenA))

STDStretch32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [6], header = None)
STDStretch32__ = STDStretch32_.values
STDStretch32 = np.reshape(STDStretch32__,(LenW,lenA))

fname3 = 'Excessr34tau0.dat'
lenA = 17 #11
a_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [0], header = None)
a__ = a_.values
a34 = np.reshape(a__,(LenW,lenA))
Excess34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [1], header = None)
Excess34__ = Excess34_.values
ExcessR34 = np.reshape(Excess34__,(LenW,lenA))

STDExcess34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [5], header = None)
STDExcess34__ = STDExcess34_.values
STDExcessR34 = np.reshape(STDExcess34__,(LenW,lenA))

Bending34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [3], header = None)
Bending34__ = Bending34_.values
Bending34 = np.reshape(Bending34__,(LenW,lenA))

Binding34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [4], header = None)
Binding34__ = Binding34_.values
Binding34 = np.reshape(Binding34__,(LenW,lenA))

Stretch34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [2], header = None)
Stretch34__ = Stretch34_.values
Stretch34 = np.reshape(Stretch34__,(LenW,lenA))


STDBend34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [7], header = None)
STDBend34__ = STDBend34_.values
STDBend34 = np.reshape(STDBend34__,(LenW,lenA))

STDBind34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [8], header = None)
STDBind34__ = STDBind34_.values
STDBind34 = np.reshape(STDBind34__,(LenW,lenA))

STDStretch34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [6], header = None)
STDStretch34__ = STDStretch34_.values
STDStretch34 = np.reshape(STDStretch34__,(LenW,lenA))

# %%
cmap = plt.cm.get_cmap('BuPu') #twilight'YlOrBr''BuPu_r')
cmap2 = plt.cm.get_cmap('YlOrBr') #twilight'YlOrBr''BuPu_r')

fig,ax= plt.subplots(1,5,figsize = (30,5))
#fig2,ax2= plt.subplots(1,figsize = (5,4))

Total32 = []  
for x in range(5):
    if x ==1:
        print('got here')
        Excess16 = ExcessR16
        Excess32 = ExcessR32
        STDExcess16 = STDExcessR16
        STDExcess32 = STDExcessR32
        Excess18 = ExcessR18
        Excess34 = ExcessR34
        STDExcess18 = STDExcessR18
        STDExcess34 = STDExcessR34
    if x ==2:
        Excess16 = Bending16
        Excess32 = Bending32
        STDExcess16 = STDBend16
        STDExcess32 = STDBend32
        Excess18 = Bending18
        Excess34 = Bending34
        STDExcess18 = STDBend18
        STDExcess34 = STDBend34
    if x ==3:
        Excess16 = Stretch16
        Excess18 = Stretch18
        Excess32 = Stretch32
        Excess34 = Stretch34
        STDExcess16 = STDStretch16
        STDExcess32 = STDStretch32
        STDExcess18 = STDStretch18
        STDExcess34 = STDStretch34
    if x ==4:
        Excess16 = Binding16
        Excess32 = Binding32
        STDExcess16 = STDBind16
        STDExcess32 = STDBind32
        Excess18 = Binding18
        Excess34 = Binding34
        STDExcess18 = STDBind18
        STDExcess34 = STDBind34
    if x ==0:
        Excess16 = Binding16+ExcessR16
        Excess32 = Binding32+ExcessR32
        STDExcess16 = STDBind16 +STDExcessR16
        STDExcess32 = STDBind32+STDExcessR32
        Excess18 = Binding18+ExcessR18
        Excess34 = Binding34+ExcessR34
        STDExcess18 = STDBind18+STDExcessR18
        STDExcess34 = STDBind34+STDExcessR34
    
    for w in range(1):
        wind = 0 #w*2
        endval = Excess32[wind,len(a32[0])-5]
        endval2 = Excess32[wind,len(a32[0])-5] #Excess32[wind,len(a32[0])-9] #len(a[0])-2
        endval3 = Excess32[wind,len(a32[0])-5]
        endval4 = Excess32[wind,len(a32[0])-5] #len(a[0])-2
        clr2 = cmap((10)/(12))
        clr1 = 'mediumseagreen' #cmap((8)/(12))
        clr4 = cmap2((10)/(12))
        clr3 = 'tab:blue' #cmap2((8)/(12))
        aend = 1
        ax[x].plot(a18[wind,1:],Excess18[wind,1:]-endval3, color = clr2,linewidth  = 2,marker = 'o',linestyle = '-',markersize = 7, label = "r = 1.8, Av up to w = "+str(269+wind))
        ax[x].fill_between(a18[wind,1:], Excess18[wind,1:]-STDExcess18[wind,1:]-endval3,Excess18[wind,1:]+STDExcess18[wind,1:]-endval3, color = clr2,alpha = 0.2)
        #ax[x].errorbar(a32[wind,1:-aend],Excess32[wind,1:-aend]-endval2,yerr = STDExcess32[wind,1:-aend],capsize = 3, color = clr3,linewidth  = 2,marker = 'X',fillstyle = 'none',linestyle = '',markersize = 7, label = "r = 3.2, Av up to w = "+str(269+wind))
        ax[x].plot(a32[wind,1:-aend],Excess32[wind,1:-aend]-endval2,color = clr3,linewidth  = 2,marker = 'X',linestyle = '-',markersize = 7, label = "r = 3.2, Av up to w = "+str(269+wind))
        ax[x].fill_between(a32[wind,1:-aend], Excess32[wind,1:-aend]-STDExcess32[wind,1:-aend]-endval2,Excess32[wind,1:-aend]+STDExcess32[wind,1:-aend]-endval2, color = clr3,alpha = 0.2)
        ax[x].plot(a34[wind,1:],Excess34[wind,1:]-endval4, color = clr4,linewidth  = 2,marker = 'o',linestyle = '-',markersize = 7, label = "r = 3.4, Av up to w = "+str(269+wind))
        ax[x].fill_between(a34[wind,1:], Excess34[wind,1:]-STDExcess34[wind,1:]-endval4,Excess34[wind,1:]+STDExcess34[wind,1:]-endval4, color = clr4,alpha = 0.2)
        #ax[x].errorbar(a[wind,1:-aend],Excess16[wind,1:-aend]-endval,yerr = STDExcess16[wind,1:-aend], color = clr1,linewidth  = 2,marker = 'o',fillstyle = 'none',linestyle = '',markersize = 7, label = "r = 1.6, Av up to w = "+str(269+wind))
        ax[x].plot(a[wind,:-aend],Excess16[wind,:-aend]-endval, color = clr1,linewidth  = 2,marker = 'o',linestyle = '-',markersize = 7, label = "r = 1.6, Av up to w = "+str(269+wind))
        ax[x].fill_between(a[wind,:-aend], Excess16[wind,:-aend]-STDExcess16[wind,:-aend]-endval,Excess16[wind,:-aend]+STDExcess16[wind,:-aend]-endval, color = clr1,alpha = 0.2)

#ax2.plot(a[wind],Total32, color = clr2,linewidth  = 2,marker = 'o',linestyle = '',markersize = 7, label = "r = 1.8, Av up to w = "+str(269+wind))
#ax2.fill_between(a32[wind], Excess34[wind]-STDExcess34[wind]-endval4,Excess34[wind]+STDExcess34[wind]-endval4, color = clr4,alpha = 0.2)
    
#ax[0].set_ylim([-12,7])
#ax[1].set_ylim([-12,7])
#ax[2].set_ylim([-12,7])
#ax[3].set_ylim([-1715,-1735])
ax[0].set_xlim([1.5,5.5])
ax[1].set_xlim([1.5,5.5])
ax[2].set_xlim([1.5,5.5])
ax[0].set_ylim([-10,10])
ax[1].set_ylim([-10,10])
ax[2].set_ylim([-10,10])
ax[3].set_ylim([-10,10])
ax[4].set_ylim([-10,10])
#ax[1].set_ylim([3675,3695])
#ax[2].set_ylim([850,870])
#ax[0].set_ylim([4535,4555])
ax[3].legend(frameon=False)
ax[0].set_title(r'$\tau = 0$, line', fontsize  = 14)
ax[0].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14)
ax[1].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14)
ax[2].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14)
ax[3].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14)
ax[4].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14)
ax[1].set_ylabel(r'Excess Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
ax[2].set_ylabel(r'Bending Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
ax[3].set_ylabel(r'Stretching Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
ax[4].set_ylabel(r'Binding Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
ax[0].set_ylabel(r'Total Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
plt.tight_layout()
#fname = 'tau90_16_32_28k.pdf'
#fig.savefig(plotsdir+fname)
# Out:
# got here

# %%
fname1 = 'Excessr16tau0_bin2.dat'
LenA = 13 #21
LenW = 1
a_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [0], header = None)
a__ = a_.values
a = np.reshape(a__,(LenW,LenA))
Excess16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [1], header = None)
Excess16__ = Excess16_.values
ExcessR16 = np.reshape(Excess16__,(LenW,LenA))

Bending16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [3], header = None)
Bending16__ = Bending16_.values
Bending16 = np.reshape(Bending16__,(LenW,LenA))

Binding16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [4], header = None)
Binding16__ = Binding16_.values
Binding16 = np.reshape(Binding16__,(LenW,LenA))

Stretch16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [2], header = None)
Stretch16__ = Stretch16_.values
Stretch16 = np.reshape(Stretch16__,(LenW,LenA))

STDExcess16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [5], header = None)
STDExcess16__ = STDExcess16_.values
STDExcessR16 = np.reshape(STDExcess16__,(LenW,LenA))

STDBend16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [7], header = None)
STDBend16__ = STDBend16_.values
STDBend16 = np.reshape(STDBend16__,(LenW,LenA))

STDBind16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [8], header = None)
STDBind16__ = STDBind16_.values
STDBind16 = np.reshape(STDBind16__,(LenW,LenA))

STDStretch16_ = pandas.read_csv(datadir  + fname1, sep=' ', usecols = [6], header = None)
STDStretch16__ = STDStretch16_.values
STDStretch16 = np.reshape(STDStretch16__,(LenW,LenA))

fname11 = 'Excessr18tau0_bin2.dat'
LenA = 13 #13
a_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [0], header = None)
a__ = a_.values
a18 = np.reshape(a__,(LenW,LenA))
Excess18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [1], header = None)
Excess18__ = Excess18_.values
ExcessR18 = np.reshape(Excess18__,(LenW,LenA))

Bending18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [3], header = None)
Bending18__ = Bending18_.values
Bending18 = np.reshape(Bending18__,(LenW,LenA))

Binding18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [4], header = None)
Binding18__ = Binding18_.values
Binding18 = np.reshape(Binding18__,(LenW,LenA))

Stretch18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [2], header = None)
Stretch18__ = Stretch18_.values
Stretch18 = np.reshape(Stretch18__,(LenW,LenA))

STDExcess18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [5], header = None)
STDExcess18__ = STDExcess18_.values
STDExcessR18 = np.reshape(STDExcess18__,(LenW,LenA))

STDBend18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [7], header = None)
STDBend18__ = STDBend18_.values
STDBend18 = np.reshape(STDBend18__,(LenW,LenA))

STDBind18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [8], header = None)
STDBind18__ = STDBind18_.values
STDBind18 = np.reshape(STDBind18__,(LenW,LenA))

STDStretch18_ = pandas.read_csv(datadir  + fname11, sep=' ', usecols = [6], header = None)
STDStretch18__ = STDStretch18_.values
STDStretch18 = np.reshape(STDStretch18__,(LenW,LenA))



fname2 = 'Excessr32tau0_bin2.dat'
lenA = 13 #22
Excess32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [1], header = None)
Excess32__ = Excess32_.values
ExcessR32 = np.reshape(Excess32__,(LenW,lenA))
a_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [0], header = None)
a__ = a_.values
a32 = np.reshape(a__,(LenW,lenA))
STDExcess32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [5], header = None)
STDExcess32__ = STDExcess32_.values
STDExcessR32 = np.reshape(STDExcess32__,(LenW,lenA))

Bending32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [3], header = None)
Bending32__ = Bending32_.values
Bending32 = np.reshape(Bending32__,(LenW,lenA))

Binding32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [4], header = None)
Binding32__ = Binding32_.values
Binding32 = np.reshape(Binding32__,(LenW,lenA))

Stretch32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [2], header = None)
Stretch32__ = Stretch32_.values
Stretch32 = np.reshape(Stretch32__,(LenW,lenA))

STDBind32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [8], header = None)
STDBind32__ = STDBind32_.values
STDBind32 = np.reshape(STDBind32__,(LenW,lenA))

STDBend32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [7], header = None)
STDBend32__ = STDBend32_.values
STDBend32 = np.reshape(STDBend32__,(LenW,lenA))

STDStretch32_ = pandas.read_csv(datadir  + fname2, sep=' ', usecols = [6], header = None)
STDStretch32__ = STDStretch32_.values
STDStretch32 = np.reshape(STDStretch32__,(LenW,lenA))

fname3 = 'Excessr34tau0_bin2.dat'
lenA = 13 #11
a_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [0], header = None)
a__ = a_.values
a34 = np.reshape(a__,(LenW,lenA))
Excess34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [1], header = None)
Excess34__ = Excess34_.values
ExcessR34 = np.reshape(Excess34__,(LenW,lenA))

STDExcess34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [5], header = None)
STDExcess34__ = STDExcess34_.values
STDExcessR34 = np.reshape(STDExcess34__,(LenW,lenA))

Bending34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [3], header = None)
Bending34__ = Bending34_.values
Bending34 = np.reshape(Bending34__,(LenW,lenA))

Binding34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [4], header = None)
Binding34__ = Binding34_.values
Binding34 = np.reshape(Binding34__,(LenW,lenA))

Stretch34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [2], header = None)
Stretch34__ = Stretch34_.values
Stretch34 = np.reshape(Stretch34__,(LenW,lenA))


STDBend34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [7], header = None)
STDBend34__ = STDBend34_.values
STDBend34 = np.reshape(STDBend34__,(LenW,lenA))

STDBind34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [8], header = None)
STDBind34__ = STDBind34_.values
STDBind34 = np.reshape(STDBind34__,(LenW,lenA))

STDStretch34_ = pandas.read_csv(datadir  + fname3, sep=' ', usecols = [6], header = None)
STDStretch34__ = STDStretch34_.values
STDStretch34 = np.reshape(STDStretch34__,(LenW,lenA))

# %%
cmap = plt.cm.get_cmap('BuPu') #twilight'YlOrBr''BuPu_r')
cmap2 = plt.cm.get_cmap('YlOrBr') #twilight'YlOrBr''BuPu_r')

fig,ax= plt.subplots(1,4,figsize = (16,4))
#fig2,ax2= plt.subplots(1,figsize = (5,4))

Total32 = []  
for x in range(4):
    if x ==0:
        print('got here')
        Excess16 = ExcessR16
        Excess32 = ExcessR32
        STDExcess16 = STDExcessR16
        STDExcess32 = STDExcessR32
        Excess18 = ExcessR18
        Excess34 = ExcessR34
        STDExcess18 = STDExcessR18
        STDExcess34 = STDExcessR34
    if x ==1:
        Excess16 = Bending16
        Excess32 = Bending32
        STDExcess16 = STDBend16
        STDExcess32 = STDBend32
        Excess18 = Bending18
        Excess34 = Bending34
        STDExcess18 = STDBend18
        STDExcess34 = STDBend34
    if x ==2:
        Excess16 = Stretch16
        Excess18 = Stretch18
        Excess32 = Stretch32
        Excess34 = Stretch34
        STDExcess16 = STDStretch16
        STDExcess32 = STDStretch32
        STDExcess18 = STDStretch18
        STDExcess34 = STDStretch34
    if x ==3:
        Excess16 = Binding16
        Excess32 = Binding32
        STDExcess16 = STDBind16
        STDExcess32 = STDBind32
        Excess18 = Binding18
        Excess34 = Binding34
        STDExcess18 = STDBind18
        STDExcess34 = STDBind34
    if x ==4:
        Excess16 = Binding16+ExcessR16 
        Excess32 = Binding32+ExcessR32
        STDExcess16 = STDBind16 +STDExcessR16
        STDExcess32 = STDBind32+STDExcessR32
        Excess18 = Binding18+ExcessR18
        Excess34 = Binding34+ExcessR34
        STDExcess18 = STDBind18+STDExcessR18
        STDExcess34 = STDBind34+STDExcessR34
    
    for w in range(1):
        wind = 0 #w*2
        endval = Excess16[wind,-2] +3#+3
        endval2 =  Excess16[wind,-2]+3 #Excess32[wind,len(a32[0])-9] #len(a[0])-2
        endval3 =  Excess16[wind,-2] +3#+3
        endval4 = Excess16[wind,-2]+5 #Excess34[wind,-2] #len(a[0])-2
        clr2 = 'mediumseagreen'
        clr1 = 'mediumseagreen' #cmap((8)/(12))
        clr4 = 'tab:blue' #cmap2((10)/(12))
        clr3 = 'tab:blue' #cmap2((8)/(12))
        aend = 1
        #ax[x].plot(a18[wind],Excess18[wind]-endval3, color = clr2,linewidth  = 2,marker = 'o',fillstyle = 'none',linestyle = '-',markersize = 11, label = "r = 1.8, Av up to w = "+str(269+wind))
        #ax[x].fill_between(a18[wind], Excess18[wind]-STDExcess18[wind]-endval3,Excess18[wind]+STDExcess18[wind]-endval3, color = clr2,alpha = 0.2)
        #ax[x].errorbar(a32[wind,:],Excess32[wind,:]-endval2,yerr = STDExcess32[wind,:],capsize = 3, color = clr3,linewidth  = 2,marker = 'X',fillstyle = 'none',linestyle = '',markersize = 7, label = "r = 3.2, Av up to w = "+str(269+wind))
        #ax[x].plot(a32[wind,:],Excess32[wind,:]-endval2,color = clr3,linewidth  = 2,marker = 'X',fillstyle = 'none',linestyle = '-',markersize = 11, label = "r = 3.2, Av up to w = "+str(269+wind))
        #ax[x].fill_between(a32[wind,:], Excess32[wind,:]-STDExcess32[wind,:]-endval2,Excess32[wind,:]+STDExcess32[wind,:]-endval2, color = clr3,alpha = 0.2)
        ax[x].plot(a34[wind,1:]+0.8,Excess34[wind,1:]-endval4, color = clr4,linewidth  = 2,marker = 'X',linestyle = '-',markersize = 11, label = "r = 3.4") #, Av up to w = "+str(269+wind)
        ax[x].fill_between(a34[wind,1:]+0.8, Excess34[wind,1:]-STDExcess34[wind,1:]-endval4,Excess34[wind,1:]+STDExcess34[wind,1:]-endval4, color = clr4,alpha = 0.2)
        #ax[x].errorbar(a[wind,1:-aend],Excess16[wind,1:-aend]-endval,yerr = STDExcess16[wind,1:-aend], color = clr1,linewidth  = 2,marker = 'o',fillstyle = 'none',linestyle = '',markersize = 7, label = "r = 1.6, Av up to w = "+str(269+wind))
        ax[x].plot(a[wind,1:]+0.8,Excess16[wind,1:]-endval, color = clr1,linewidth  = 2,marker = 'o',linestyle = '-',markersize = 11, label = "r = 1.6")
        ax[x].fill_between(a[wind,1:]+0.8, Excess16[wind,1:]-STDExcess16[wind,1:]-endval,Excess16[wind,1:]+STDExcess16[wind,1:]-endval, color = clr1,alpha = 0.2)

#ax2.plot(a[wind],Total32, color = clr2,linewidth  = 2,marker = 'o',linestyle = '',markersize = 7, label = "r = 1.8, Av up to w = "+str(269+wind))
#ax2.fill_between(a32[wind], Excess34[wind]-STDExcess34[wind]-endval4,Excess34[wind]+STDExcess34[wind]-endval4, color = clr4,alpha = 0.2)
    
#ax[0].set_ylim([-12,7])
#ax[1].set_ylim([-12,7])
#ax[2].set_ylim([-12,7])
#ax[3].set_ylim([-1715,-1735])
#ax[0].set_ylim([2815,2830])
ax[0].set_ylim([4538,4553])
ax[1].set_ylim([3678,3693])
ax[2].set_ylim([853,868])
ax[3].set_ylim([-1715,-1730])
ax[0].set_ylim([-7,5])
ax[1].set_ylim([-7,5])
ax[2].set_ylim([-7,5])
ax[3].set_ylim([-7,5])
ax[0].set_xlim([2.5,6.5])
ax[1].set_xlim([2.5,6.5])
ax[2].set_xlim([2.5,6.5])
ax[3].set_xlim([2.5,6.5])
#ax[1].set_ylim([3675,3695])
#ax[2].set_ylim([850,870])
#ax[0].set_ylim([4535,4555])
ax[0].legend(frameon=False, loc = [0.1,0.8])
ax[0].set_title(r'$\tau = 0^{\circ}$, linear', fontsize  = 14)
#ax[0].set_xlabel(r'$\ell~ [D_{\mathrm{bead}}]$', fontsize  = 14)
#ax[1].set_xlabel(r'$\ell~ [D_{\mathrm{bead}}]$', fontsize  = 14)
#ax[2].set_xlabel(r'$\ell~ [D_{\mathrm{bead}}]$', fontsize  = 14)
#ax[3].set_xlabel(r'$\ell~ [D_{\mathrm{bead}}]$', fontsize  = 14) #+0.9
ax[0].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14)
ax[1].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14)
ax[2].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14)
ax[3].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14) #+0.9
#ax[0].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14)
ax[0].set_ylabel(r'Excess Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
ax[1].set_ylabel(r'Bending Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
ax[2].set_ylabel(r'Stretching Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
ax[3].set_ylabel(r'Binding Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
#ax[4].set_ylabel(r'Total Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
plt.tight_layout()
fname = 'tau0_16_34_bin2_s.pdf'
#fig.savefig(plotsdir+fname)
# Out:
# got here

# %%
fname = 'data_for_billie.csv'

ell_ = pandas.read_csv(datadir  + fname, sep=',', usecols = [0],header = 'infer')
interaction18_ = pandas.read_csv(datadir  + fname, sep=',', usecols = [1], header = 'infer')
interaction30_ = pandas.read_csv(datadir  + fname, sep=',', usecols = [3], header = 'infer')
ell = ell_.values
#print(s)
interaction18 = interaction18_.values
interaction30 = interaction30_.values
fig,ax = plt.subplots()
ax.plot(ell,interaction30)
interaction30N = np.append(interaction30[1],interaction30[3:])
ellN = np.append(ell[1],ell[3:])
print(interaction30N)
# Out:
# [ 2.22702438 -0.18950498 -1.91457307 -2.71569971 -2.23229393 -1.60044124
#  -1.40582725 -1.26726343 -0.89421298 -0.2297114  -0.39980038 -0.27808498
#   0.37502483 -0.11260199  0.18226839  0.34314962 -0.04980822]

# %%
cmap = plt.cm.get_cmap('BuPu') #twilight'YlOrBr''BuPu_r')
cmap2 = plt.cm.get_cmap('YlOrBr') #twilight'YlOrBr''BuPu_r')

fig,ax= plt.subplots(1,4,figsize = (16,4))
#fig2,ax2= plt.subplots(1,figsize = (5,4))
ax[0].plot(ellN,interaction30N, color = clr4,linewidth  = 3,marker = 'X',markersize = 5,linestyle = ':',label = 'Experiment $r = 3.0~ D$')
ax[0].plot(ell,interaction18,color = clr1,linewidth  = 3,marker = 'o',markersize = 5,linestyle = ':',label = 'Experiment $r = 1.8~ D$')
#ax[0].plot(ell,interaction18,color = clr1,linewidth  = 3,marker = 'o',markersize = 5,alpha = 0.0,linestyle = ':')

Total32 = []  
for x in range(4):
    if x ==0:
        print('got here')
        Excess16 = ExcessR16
        Excess32 = ExcessR32
        STDExcess16 = STDExcessR16
        STDExcess32 = STDExcessR32
        Excess18 = ExcessR18
        Excess34 = ExcessR34
        STDExcess18 = STDExcessR18
        STDExcess34 = STDExcessR34
    if x ==1:
        Excess16 = Bending16
        Excess32 = Bending32
        STDExcess16 = STDBend16
        STDExcess32 = STDBend32
        Excess18 = Bending18
        Excess34 = Bending34
        STDExcess18 = STDBend18
        STDExcess34 = STDBend34
    if x ==2:
        Excess16 = Stretch16
        Excess18 = Stretch18
        Excess32 = Stretch32
        Excess34 = Stretch34
        STDExcess16 = STDStretch16
        STDExcess32 = STDStretch32
        STDExcess18 = STDStretch18
        STDExcess34 = STDStretch34
    if x ==3:
        Excess16 = Binding16
        Excess32 = Binding32
        STDExcess16 = STDBind16
        STDExcess32 = STDBind32
        Excess18 = Binding18
        Excess34 = Binding34
        STDExcess18 = STDBind18
        STDExcess34 = STDBind34
    if x ==4:
        Excess16 = Binding16+ExcessR16 
        Excess32 = Binding32+ExcessR32
        STDExcess16 = STDBind16 +STDExcessR16
        STDExcess32 = STDBind32+STDExcessR32
        Excess18 = Binding18+ExcessR18
        Excess34 = Binding34+ExcessR34
        STDExcess18 = STDBind18+STDExcessR18
        STDExcess34 = STDBind34+STDExcessR34
    
    for w in range(1):
        wind = 0 #w*2
        endval = Excess16[wind,-2] +3#+3
        endval2 =  Excess16[wind,-2]+3 #Excess32[wind,len(a32[0])-9] #len(a[0])-2
        endval3 =  Excess16[wind,-2] +3#+3
        endval4 = Excess16[wind,-2]+5 #Excess34[wind,-2] #len(a[0])-2
        clr2 = 'mediumseagreen'
        clr1 = 'mediumseagreen' #cmap((8)/(12))
        clr4 = 'tab:blue' #cmap2((10)/(12))
        clr3 = 'tab:blue' #cmap2((8)/(12))
        aend = 1
        ax[x].plot(a34[wind,1:]+0.8,Excess34[wind,1:]-endval4, color = clr4,linewidth  = 2,marker = 'X',linestyle = '-',markersize = 7, label = "Simulation $r = 3.4~ D$") #, Av up to w = "+str(269+wind)
        ax[x].fill_between(a34[wind,1:]+0.8, Excess34[wind,1:]-STDExcess34[wind,1:]-endval4,Excess34[wind,1:]+STDExcess34[wind,1:]-endval4, color = clr4,alpha = 0.2)
        ax[x].plot(a[wind,1:]+0.8,Excess16[wind,1:]-endval, color = clr1,linewidth  = 2,marker = 'o',linestyle = '-',markersize = 7, label = "Simulation $r = 1.6~ D$")
        ax[x].fill_between(a[wind,1:]+0.8, Excess16[wind,1:]-STDExcess16[wind,1:]-endval,Excess16[wind,1:]+STDExcess16[wind,1:]-endval, color = clr1,alpha = 0.2)
        #ax[x].plot(a[wind,1:]+0.8,Excess16[wind,1:]-endval, color = clr1,linewidth  = 2,alpha = 0,marker = 'o',linestyle = '-',markersize = 7)
        #ax[x].fill_between(a[wind,1:]+0.8, Excess16[wind,1:]-STDExcess16[wind,1:]-endval,Excess16[wind,1:]+STDExcess16[wind,1:]-endval, color = clr1,alpha = 0.0)

ax[0].set_ylim([4538,4553])
ax[1].set_ylim([3678,3693])
ax[2].set_ylim([853,868])
ax[3].set_ylim([-1715,-1730])
ax[0].set_ylim([-6,6.5])
ax[1].set_ylim([-6,6.5])
ax[2].set_ylim([-6,6.5])
ax[3].set_ylim([-6,6.5])
ax[0].set_xlim([2.,6.])
ax[1].set_xlim([2.,6.])
ax[2].set_xlim([2.,6.])
ax[3].set_xlim([2.,6.])
#ax[1].set_ylim([3675,3695])
#ax[2].set_ylim([850,870])
#ax[0].set_ylim([4535,4555])
ax[0].legend(frameon=False, loc = [0.02,0.69])
#ax[0].set_title(r'$\tau = 0^{\circ}$, linear', fontsize  = 14)
ax[0].set_xlabel(r'$\ell~ [D]$', fontsize  = 14)
ax[1].set_xlabel(r'$\ell~ [D]$', fontsize  = 14)
ax[2].set_xlabel(r'$\ell~ [D]$', fontsize  = 14)
ax[3].set_xlabel(r'$\ell~ [D]$', fontsize  = 14) #+0.9

#ax[0].set_xlabel(r'$s~ [D_{\mathrm{bead}}]$', fontsize  = 14)
ax[0].set_ylabel(r'$\Delta E$ [$k_{\mathrm{B}}T$]', fontsize  = 14)
ax[1].set_ylabel(r'Bending Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
ax[2].set_ylabel(r'Stretching Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
ax[3].set_ylabel(r'Binding Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
#ax[4].set_ylabel(r'Total Energy [$k_{\mathrm{B}}T$]', fontsize  = 14)
plt.tight_layout()
fname = 'tau0_16_34_bin2_ell_wtExp_SimLeg_2.pdf'
fig.savefig(plotsdir+fname)
# Out:
# got here
