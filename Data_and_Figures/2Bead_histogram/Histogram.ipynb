# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
import pandas
import numpy as np
import matplotlib.pyplot as plt
import os.path
import numbers

datadir = '/Users/billiemeadowcroft/Dropbox/PhDGithub/RemoteTether/Data_and_Figures/2Bead_histogram/Data/'
plotsdir = '/Users/billiemeadowcroft/Dropbox/PhDGithub/RemoteTether/Data_and_Figures/2Bead_histogram/Plots/'
clrs = ['#2c7fb8','#41b6c4','#7fcdbb']
cmap = plt.cm.get_cmap('twilight')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fig1,ax1 = plt.subplots(figsize = (4,4))
fig,ax = plt.subplots(2,2,figsize = (4,4))
arrsecs = [0,22,30,70,71,300,301,450] #20,35,50,163,257,333,450] 0,34,35,60,61,300,301,450
s = [1.5,1.7, 1.9, 2.5,4.0]
arc1 = "10 11 18 28".split()
cmap1 = plt.cm.get_cmap('twilight') #PuBu
cmap2 = plt.cm.get_cmap('YlOrBr')
plt.rcParams.update({'font.size': 11})
mark = 5
a1=450
cmap = cmap1
for a2 in range(len(arc1)-1):
    clr = cmap((a2+1)/(len(arc1)+1))
    if a2 > 0:
        a2+=1
    fname = 'hist'+str(arc1[a2])+'.txt'
    hist = pandas.read_csv(datadir  + fname, sep=' ', header = 'infer')
    My_Bind = hist.My_bind
    histnorm = hist.Hist
    histReW = hist.HistReWeighted
    #ax[0].plot(My_Bind+0.002*a1,histReW,color = clr, linestyle ='-',marker = mark,alpha= 0.5,markersize = 5,label = r's = '+str(arc1[a2]))
    ax[0,0].plot(My_Bind,histnorm,color = clr, linestyle ='-',marker = mark,alpha= 0.5,markersize = 5,label = r's = '+str(arc1[a2]))
    #ax2[0].plot(My_Bind+0.002*a1,histReW,color = clr, linestyle ='-',marker = mark,alpha= 0.5,markersize = 5,label = r's = '+str(arc1[a2]))
    #ax1.plot(My_Bind,histReW,color = clr, linestyle ='-',marker = mark,alpha= 0.5,markersize = 2,label = r's = '+str(s[a2]))
    ax1.plot(My_Bind,histnorm,color = clr, linestyle ='-',marker = mark,alpha= 0.5,markersize = 2,label = r's = '+str(s[a2]))
    ax[0,1].plot(My_Bind,histnorm,color = clr, linestyle ='-',marker = mark,alpha= 0.5,markersize = 5,label = r's = '+str(s[a2]))
    ax[1,0].plot(My_Bind,histnorm,color = clr, linestyle ='-',marker = mark,alpha= 0.5,markersize = 5,label = r's = '+str(s[a2]))
    ax[1,1].plot(My_Bind,histnorm,color = clr, linestyle ='-',marker = mark,alpha= 0.5,markersize = 5,label = r's = '+str(s[a2]))
    
ax1.legend(loc = [0.58,0.7],frameon=False,fontsize = 12)

ax[0,0].set_ylim([0,1500]) 
ax[0,0].set_xlim([arrsecs[0]*0.01,arrsecs[1]*0.01]) 
ax[0,1].set_ylim([0,27]) 
ax[0,1].set_xlim([arrsecs[2]*0.01,arrsecs[3]*0.01]) 
ax[1,0].set_ylim([0.,0.4]) 
ax[1,0].set_xlim([arrsecs[4]*0.01,arrsecs[5]*0.01]) 
ax[1,1].set_ylim([0.,0.25]) 
ax[1,1].set_xlim([arrsecs[6]*0.01,arrsecs[7]*0.01]) 


m = 2
#[l.set_visible(False) for (i,l) in enumerate(ax[a1,1].xaxis.get_ticklabels()) if i % m != 0]
#[l.set_visible(False) for (i,l) in enumerate(ax[a1,1].xaxis.get_ticklabels()) if i % m != 0]
ax[0,0].set_title('Vesicle beads',fontsize = 12)
ax[0,1].set_title('Colloid-bound beads',fontsize = 12)
ax[1,0].set_title('Outer neck beads',fontsize = 12)
ax[1,1].set_title('Inner neck beads',fontsize = 12)
#ax[0,0].set_xlabel(r'Bending energy [$k_{\mathrm{B}}T$]',fontsize = 14)
#ax[0,1].set_xlabel(r'Bending energy [$k_{\mathrm{B}}T$]',fontsize = 14)
ax[1,0].set_xlabel(r'Bending energy [$k_{\mathrm{B}}T$]',fontsize = 14)
#ax[1,1].set_xlabel(r'Bending energy [$k_{\mathrm{B}}T$]',fontsize = 14)


ax1.set_yscale('log')
ax1.set_ylim([0.0004,1700])

ax1.set_xlabel(r'Bending energy [$k_{\mathrm{B}}T$]',fontsize = 15)
ax1.set_ylabel(r'Bead count',fontsize = 15)
ax[0,0].set_ylabel(r'Bead count',fontsize = 15)
ax[1,0].set_ylabel(r'Bead count',fontsize = 15)
fig.align_ylabels()
#ax2[0].set_ylabel(r'Bead count',fontsize = 15)
fig1.subplots_adjust(bottom=0.2)
fig1.subplots_adjust(left=0.2)
fig.tight_layout()
fname = 'Sections_2beadv2.pdf'
fig.savefig(plotsdir+fname)
fname = 'FullLog_2beadv2.pdf'
fig1.savefig(plotsdir+fname)
